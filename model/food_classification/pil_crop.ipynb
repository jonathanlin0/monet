# %%
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import json
import torchvision
import PIL
from PIL import Image
from math import floor
from math import ceil
from statistics import median

# %%
image = PIL.Image.open("/Users/jonathanlin/Documents/GitHub/monet/model/datasets/food101/images/apple_pie/23893.jpg", mode="r")
# display image with matplotlib
plt.imshow(image)

# %%
image = image.resize((100, 100), resample=Image.Resampling.BILINEAR)
plt.imshow(image)
